# %%
import quandl
import googlemaps
import dbnomics
import pageviewapi

# %% [markdown]
# # Quandl

# %%
data=quandl.get("FRED/GDP",start_date="2001-12-31",end_date="2005-12-31",collapse="quarterly") #GDP and unemployment rates of USA
#data=quandl.get(["WIKI/AAPL/","WIKI/TSLA"]) data of APPLE and TESLA

# %%
data.head()
# Out:
#                 Value
# Date
# 2002-03-31  10788.952
# 2002-06-30  10893.207
# 2002-09-30  10992.051
# 2002-12-31  11071.463
# 2003-03-31  11183.507

# %% [markdown]
# # DBnomics

# %%
from dbnomics import fetch_series

# %%
data=fetch_series("AMECO/ZUTN/EA19.1.0.0.0.ZUTN")

# %%
print(data.head())
# Out:
#   @frequency provider_code dataset_code  \
# 0     annual         AMECO         ZUTN
# 1     annual         AMECO         ZUTN
# 2     annual         AMECO         ZUTN
# 3     annual         AMECO         ZUTN
# 4     annual         AMECO         ZUTN
#
#                                         dataset_name        series_code  \
# 0  Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# 1  Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# 2  Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# 3  Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# 4  Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
#
#                                          series_name  \
# 0  Annually – (Percentage of active population) –...
# 1  Annually – (Percentage of active population) –...
# 2  Annually – (Percentage of active population) –...
# 3  Annually – (Percentage of active population) –...
# ...

# %%
import pageviewapi

# %%
pageviewapi.top("en.wikipedia", 2018, 12, 14,access="all-access")
# Out:
# AttrDict({'items': [{'project': 'en.wikipedia', 'access': 'all-access', 'year': '2018', 'month': '12', 'day': '14', 'articles': [{'article': 'Main_Page', 'views': 14640903, 'rank': 1}, {'article': 'Special:Search', 'views': 1687886, 'rank': 2}, {'article': 'Jason_Momoa', 'views': 421592, 'rank': 3}, {'article': 'Louis_Tomlinson', 'views': 256048, 'rank': 4}, {'article': 'Sondra_Locke', 'views': 219955, 'rank': 5}, {'article': 'List_of_most-disliked_YouTube_videos', 'views': 217056, 'rank': 6}, {'article': 'Lisa_Bonet', 'views': 189152, 'rank': 7}, {'article': 'Aquaman_(film)', 'views': 185974, 'rank': 8}, {'article': 'Exo_(band)', 'views': 175010, 'rank': 9}, {'article': 'Patrick_Mahomes', 'views': 166068, 'rank': 10}, {'article': 'Special:CreateAccount', 'views': 163929, 'rank': 11}, {'article': 'Spider-Man:_Into_the_Spider-Verse', 'views': 152993, 'rank': 12}, {'article': 'Eliza_Dushku', 'views': 138690, 'rank': 13}, {'article': 'XHamster', 'views': 137108, 'rank': 14}, {'article':
# ...

# %% [markdown]
# # Google Maps

# %%
import googlemaps

# %%
api_key="AIzaSyBAURyar7yjvtYn0ayYAVv9ZRPxUP8qH2c"

# %%
gmaps=googlemaps.Client(key=api_key)

# %%
gmaps.geocode("American University of Armenia, Yerevan, Armenia")
# Out:
# [{'address_components': [{'long_name': '40',
#     'short_name': '40',
#     'types': ['street_number']},
#    {'long_name': 'Marshal Baghramyan Avenue',
#     'short_name': 'Marshal Baghramyan Ave',
#     'types': ['route']},
#    {'long_name': 'Kentron',
#     'short_name': 'Kentron',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Yerevan',
#     'short_name': 'Yerevan',
#     'types': ['locality', 'political']},
#    {'long_name': 'Yerevan',
#     'short_name': 'Yerevan',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Armenia',
#     'short_name': 'AM',
#     'types': ['country', 'political']},
#    {'long_name': '0019', 'short_name': '0019', 'types': ['postal_code']}],
#   'formatted_address': '40 Marshal Baghramyan Ave, Yerevan 0019, Armenia',
#   'geometry': {'location': {'lat': 40.1930377, 'lng': 44.5044753},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 40.19438668029149,
# ...
